# %% [markdown]
# # **GirlSET Workshop: Brief Introduction to Software Engineering for Artificial Intelligence (SE4AI)**
# # Python coding activity

# %% [markdown]
# # Step 1: Variables
#
# In this first step, we will begin by:
#
# * Declaring and assigning values to variables of different types.

# %% [markdown]
# **Write the code** to create the variables A, B, C

# %%
# Write code here

# %% [markdown]
# **Write the code** to assign and print the following values to each variable:
# * A: 2
# * B: 2
# * C: 4
#
# **Question:** what type of variable is this?

# %%
# Write code here

# %% [markdown]
# **Write the code** to re-assign and print the following values to each variable:
# * A: 2.5
# * B: 2.5
# * C: 4.5
#
# **Question:** what type of variable is this?

# %%
# Write code here

# %% [markdown]
# **Write the code** to assign and print the following values to each variable:
# * D: Hello
# * E: World
# * F: !
#
# **Question:** what type of variable is this?

# %%
# Write code below

# %% [markdown]
# **Write the code** to assign and print the following values to each variable:
# * list_1: contains A, C, E
# * list_2: contains D, E, F
#
# **Question:** what types of variables are these?

# %%
# Write code here

# %% [markdown]
# **Write the code** to assign and print the following values to each variable:
# * x_coordinate: 10
# * y_coordinate: 5
# * coordinate: (x, y)
#
# **Question:** what type of variable is this?

# %%
# Write code here

# %% [markdown]
# **Write the code** to assign and print the following values to each variable:
# * person_1:
#     * first_name: Jane
#     * last_name: Doe
#     * age: 30
#
#
# * person_2:
#     * first_name: John
#     * last_name: Smith
#     * age: 25
#
# **Question:** what type of variable is this?

# %%
# Write code here

# %% [markdown]
# # Step 2: Comparison and math operators
#
# * ==
# * !=
# * <, >, >=

# %% [markdown]
# **Write the code** to compare and print the results of the following:
#
# * is A the same as B?
# * is person_1 different from person_2?
# * is C less than or equal to A?
# * is D greater than or equal to E?

# %%
# Write code here

# Part 1


# Part 2


# Part 3


# Part 4

# %% [markdown]
# **Write the code** to perform the following math operations:
#
# * What is the multiplication of A, B, and C?
# * What is the sum of D, E, and F?

# %%
# Write code here

# Part 1


# Part 2

# %% [markdown]
# **Write the code** for the quadratic equation using variables A, B, and C:
#
# ![image.png](attachment:08087206-88bf-4f55-a583-e003dc440c8a.png)

# %%
# Write code here

# %% [markdown]
# # Step 3: Logic operators
#
# * or
# * and
# * not

# %% [markdown]
# **Write the code** to compare and print the results of the following:
#
# * A has the same value as B or A has the same value as C.
# * A has the same value as B and A has the same value as C.
# * B has a different value from A.
# * B is not less than C and B is greater than or equal to A.

# %%
# Write code here

# Part 1


# Part 2


# Part 3


# Part 4

# %% [markdown]
# # Step 4: Conditionals
#
# * if
# * if-else
# * if-elseif-else

# %% [markdown]
# **Write the code** to perform the following task:
#
# * if A is the same as B, then print 'same values'.

# %%
# Write code here

# %% [markdown]
# **Write the code** to perform the following task:
#
# * If A is the same as B and B is the same as C and C is the same as A, then it’s an equilateral triangle.
# * If this is not the case, then it’s not an equilateral triangle.

# %%
# Write code here

# %% [markdown]
# **Write the code** to perform the following task:
#
# * If A is the same as B and B is the same as C and C is the same as A, then it’s an equilateral triangle.
# * If A is the same as B or B is the same as C or C is the same as A, then it’s an isosceles triangle.
# * If A is not the same as B and B is not the same as C and C is not the same as A, then it’s a scalene triangle.
# * If all this is not the case, then maybe it's not a triangle.

# %%
# Write code here

# %% [markdown]
# # Step 5: Loops
#
# * for
# * while

# %% [markdown]
# **Write the code** to perform the following task using a **for** loop:
#
# * Display the first 10 numbers of the Fibonacci sequence. Here is a hint to help code the task:
#
# ![image.png](attachment:ca64b2a0-c0a9-401c-a6e0-3e53314cef75.png)

# %%
# Write code here

# %% [markdown]
# **Write the code** for the same task above but using a **while** loop.

# %%
# Write code here

# %% [markdown]
# # Step 6: Methods/Functions
#
# In this final step, we will create:
#
# * a method with no parameters.
# * a method with parameters.

# %% [markdown]
# **Write the code** to create a method called *print_hello* which prints the string 'Hello World!' when called. Then call the method.

# %%
# Write code here

# %% [markdown]
# **Write the code** to create a method called *triangle_type* that:
#
# * accepts the variables (parameters) A, B, and C.
# * prints the type of triangle (equilateral, isosceles, scalene, maybe not a triangle).
#
# Then call the method using the variables A, B, C.

# %%
# Write code here

# %% [markdown]
# # End of Coding Activity 🎉
